# %%
print("HELLO WORLD")
# Out:
# HELLO WORLD

# %%
import pandas as pd
import numpy as np
print("Pandas version:",pd.__version__)
print("Numpy version:",np.__version__)
# Out:
# Pandas version: 2.3.3
# Numpy version: 2.3.5

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn import metrics

# %%
df = pd.read_csv("C:/Users/Dell/Desktop/car data.csv")

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# ..          ...          ...    ...
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
x = df[['Year','Present_Price','Kms_Driven','Owner']]
y = df['Selling_Price']

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
#View the first 5 rows
print(df.head())

#Check the column names
print(df.columns)

#Check datasets information
print(df.info())
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB
# None

# %%
print(df.describe())

print(df.isnull().sum())
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.show()

# %%
sns.histplot(df["Selling_Price"], kde=True)
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
print(df.isnull().sum())
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# ..          ...          ...    ...
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0
#
# [299 rows x 9 columns]

# %%
df["Car_Age"] = 2025 -df["Year"]

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  Car_Age
# 0        Dealer       Manual      0       11
# 1        Dealer       Manual      0       12
# 2        Dealer       Manual      0        8
# 3        Dealer       Manual      0       14
# 4        Dealer       Manual      0       11
# ..          ...          ...    ...      ...
# 296      Dealer       Manual      0        9
# 297      Dealer       Manual      0       10
# 298      Dealer       Manual      0       16
# 299      Dealer       Manual      0        8
# 300      Dealer       Manual      0        9
#
# [299 rows x 10 columns]

# %%
df.drop(["Car_Name","Year"], axis=1, inplace=True)

# %%
df
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0             3.35           5.59       27000    Petrol      Dealer
# 1             4.75           9.54       43000    Diesel      Dealer
# 2             7.25           9.85        6900    Petrol      Dealer
# 3             2.85           4.15        5200    Petrol      Dealer
# 4             4.60           6.87       42450    Diesel      Dealer
# ..             ...            ...         ...       ...         ...
# 296           9.50          11.60       33988    Diesel      Dealer
# 297           4.00           5.90       60000    Petrol      Dealer
# 298           3.35          11.00       87934    Petrol      Dealer
# 299          11.50          12.50        9000    Diesel      Dealer
# 300           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Car_Age
# 0         Manual      0       11
# 1         Manual      0       12
# 2         Manual      0        8
# 3         Manual      0       14
# 4         Manual      0       11
# ..           ...    ...      ...
# 296       Manual      0        9
# 297       Manual      0       10
# 298       Manual      0       16
# 299       Manual      0        8
# 300       Manual      0        9
#
# [299 rows x 8 columns]

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
X = df.drop("Selling_Price", axis=1)

Y = df["Selling_Price"]

# %%
print(X.shape)
print(Y.shape)
# Out:
# (301, 105)
# (301,)

# %%
X_train,X_test,Y_Train,Y_Test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
model= LinearRegression()

# %%
model.fit(X_train,Y_Train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
#Train the model
model = LinearRegression()
model.fit(X_train, Y_Train)

#Make Predictions
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
print("MAE=",mean_absolute_error(Y_Test,y_pred))

print("MSE=",mean_squared_error(Y_Test,y_pred))

print("RMSE =",np.sqrt(mean_squared_error(Y_Test,y_pred)))

print("R2 Score =", r2_score(Y_Test,y_pred))
# Out:
# MAE= 2.0349434490305742
# MSE= 9.225663641183456
# RMSE = 3.0373777574057947
# R2 Score = 0.5995038184050728

# %%
plt.figure(figsize=(6,6))
plt.scatter(Y_Test,y_pred)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted")
plt.show()

# %%
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
parameters = {
    "fit_intercept":[True,False]

}

grid = GridSearchCV(
    LinearRegression(),
    parameters,
    cv=5
)

grid.fit(X_train,Y_Train)

print(grid.best_params_)
# Out:
# {'fit_intercept': True}

# %%
import joblib

joblib.dump(model, "car_price_prediction.pkl")
# Out:
# ['car_price_prediction.pkl']

# %%
loaded_model = joblib.load("car_price_prediction.pkl")

# %%
print(X.columns)
# Out:
# Index(['Year', 'Present_Price', 'Kms_Driven', 'Owner', 'Car_Name_Activa 3g',
#        'Car_Name_Activa 4g', 'Car_Name_Bajaj  ct 100',
#        'Car_Name_Bajaj Avenger 150', 'Car_Name_Bajaj Avenger 150 street',
#        'Car_Name_Bajaj Avenger 220',
#        ...
#        'Car_Name_swift', 'Car_Name_sx4', 'Car_Name_verna',
#        'Car_Name_vitara brezza', 'Car_Name_wagon r', 'Car_Name_xcent',
#        'Fuel_Type_Diesel', 'Fuel_Type_Petrol', 'Seller_Type_Individual',
#        'Transmission_Manual'],
#       dtype='object', length=105)

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
print(df.columns)
# Out:
# Index(['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven', 'Owner',
#        'Car_Name_Activa 3g', 'Car_Name_Activa 4g', 'Car_Name_Bajaj  ct 100',
#        'Car_Name_Bajaj Avenger 150', 'Car_Name_Bajaj Avenger 150 street',
#        ...
#        'Car_Name_swift', 'Car_Name_sx4', 'Car_Name_verna',
#        'Car_Name_vitara brezza', 'Car_Name_wagon r', 'Car_Name_xcent',
#        'Fuel_Type_Diesel', 'Fuel_Type_Petrol', 'Seller_Type_Individual',
#        'Transmission_Manual'],
#       dtype='object', length=106)

# %%
X =df.drop("Selling_Price", axis=1)
Y =df["Selling_Price"]

# %%
X_train, X_test, Y_Train, Y_Test = train_test_split(X,Y,test_size=0.2,random_state=42)
model = LinearRegression()
model.fit(X_train, Y_Train)
# Out:
# LinearRegression()

# %%
import joblib
joblib.dump(model, "car_price_prediction.pkl")
# Out:
# ['car_price_prediction.pkl']

# %%
loaded_model = joblib.load("car_price_prediction.pkl")

sample = [[
    5.61,       #Present_Price
    27000,      #Kms_Driven
    0,          #Owner
    5,          #Car_Age
    0,          #Fuel_Type_Diesel
    1,          #Fuel_Type_Petrol
    1,          #Seller_Type_Individual
    1           #Transmission_Manual
]]

prediction = loaded_model.predict(sample)

print("Predicted Selling Price:", prediction[0])
# Out:
# C:\Users\Dell\anaconda23\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 14
#       1 loaded_model = joblib.load("car_price_prediction.pkl")
#       3 sample = [[
#       4     5.61,       #Present_Price
#       5     27000,      #Kms_Driven
#    (...)     11     1           #Transmission_Manual
#      12 ]]
# ---> 14 prediction = loaded_model.predict(sample)
#      16 print("Predicted Selling Price:", prediction[0])
#
# File ~\anaconda23\Lib\site-packages\sklearn\linear_model\_base.py:298, in LinearModel.predict(self, X)
#     284 def predict(self, X):
#     285     """
#     286     Predict using the linear model.
#     287
#    (...)    296         Returns predicted values.
#     297     """
# --> 298     return self._decision_function(X)
#
# File ~\anaconda23\Lib\site-packages\sklearn\linear_model\_base.py:277, in LinearModel._decision_function(self, X)
#     274 def _decision_function(self, X):
#     275     check_is_fitted(self)
# --> 277     X = validate_data(self, X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     278     coef_ = self.coef_
#     279     if coef_.ndim == 1:
#
# File ~\anaconda23\Lib\site-packages\sklearn\utils\validation.py:2975, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2972     out = X, y
#    2974 if not no_val_X and check_params.get("ensure_2d", True):
# -> 2975     _check_n_features(_estimator, X, reset=reset)
#    2977 return out
#
# File ~\anaconda23\Lib\site-packages\sklearn\utils\validation.py:2839, in _check_n_features(estimator, X, reset)
#    2836     return
#    2838 if n_features != estimator.n_features_in_:
# -> 2839     raise ValueError(
#    2840         f"X has {n_features} features, but {estimator.__class__.__name__} "
#    2841         f"is expecting {estimator.n_features_in_} features as input."
#    2842     )
#
# ValueError: X has 8 features, but LinearRegression is expecting 105 features as input.

# %%
print(X.shape)
print(X.columns)
# Out:
# (301, 105)
# Index(['Year', 'Present_Price', 'Kms_Driven', 'Owner', 'Car_Name_Activa 3g',
#        'Car_Name_Activa 4g', 'Car_Name_Bajaj  ct 100',
#        'Car_Name_Bajaj Avenger 150', 'Car_Name_Bajaj Avenger 150 street',
#        'Car_Name_Bajaj Avenger 220',
#        ...
#        'Car_Name_swift', 'Car_Name_sx4', 'Car_Name_verna',
#        'Car_Name_vitara brezza', 'Car_Name_wagon r', 'Car_Name_xcent',
#        'Fuel_Type_Diesel', 'Fuel_Type_Petrol', 'Seller_Type_Individual',
#        'Transmission_Manual'],
#       dtype='object', length=105)

# %%
df["Car_Age"] = 2025 - df["Year"]

# %%
print(df.columns)
# Out:
# Index(['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven', 'Owner',
#        'Car_Name_Activa 3g', 'Car_Name_Activa 4g', 'Car_Name_Bajaj  ct 100',
#        'Car_Name_Bajaj Avenger 150', 'Car_Name_Bajaj Avenger 150 street',
#        ...
#        'Car_Name_sx4', 'Car_Name_verna', 'Car_Name_vitara brezza',
#        'Car_Name_wagon r', 'Car_Name_xcent', 'Fuel_Type_Diesel',
#        'Fuel_Type_Petrol', 'Seller_Type_Individual', 'Transmission_Manual',
#        'Car_Age'],
#       dtype='object', length=107)
